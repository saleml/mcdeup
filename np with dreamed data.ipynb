# %%
# SOME DEPENDENCIES COME FROM https://github.com/EmilienDupont/neural-processes
# IF not using this repo, use bits of code to initialize another NP / another learner

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
# %matplotlib inline
from torch.utils.data import TensorDataset, DataLoader, Dataset
import torch.nn.functional as F
from torch.distributions import MultivariateNormal
from matplotlib.pyplot import cm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Neural Process for 1D functions
#
# This notebook shows how to train and sample from a Neural Process for a simple class of 1D functions. The functions are defined by f(x) = a * sin(x - b) where a and b and randomly sampled.

# %%
import torch.nn as nn
from data import generate_data, linear_quadratic

device = 'cuda' if torch.cuda.is_available() else 'cpu'

def running_mean(x, N=100):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)

# %%
(x_train, y_train, oos_x, oos_y, ood_x, ood_y, oos_x_test,
 oos_y_test, ood_x_test, ood_y_test, x_test, y_test) = generate_data(32, 32, 32, seed=7, plot=True, device=device, shuffle=True, one_sine=False, oracle=linear_quadratic)

full_X = torch.cat((x_train, ood_x, oos_x))
full_Y= torch.cat((y_train, ood_y, oos_y))
full_data = TensorDataset(full_X, full_Y)

test_data = TensorDataset(torch.cat((ood_x_test, oos_x_test)), torch.cat((ood_y_test, oos_y_test)))
oos_ood = torch.cat((ood_x, oos_x)), torch.cat((ood_y, oos_y))

# %%
class main_net(nn.Module):
    def __init__(self, input_dim=1, width=128, n_hidden=2):
        super().__init__()
        self.x_layer = nn.Linear(input_dim, width)
        self.hiddens = nn.ModuleList([nn.Linear(width, width) for _ in range(n_hidden)])
        self.output_layer = nn.Linear(width, 1)
    
    def forward(self, x):
        out = F.relu(self.x_layer(x))
        for i, l in enumerate(self.hiddens):
            out = F.relu(l(out))
        return self.output_layer(out)

LR = 3e-4
EPOCHS = 500
BS = 16
loss_fn = nn.MSELoss()

mu_net = main_net().to(device=device)
optimizer = torch.optim.Adam(mu_net.parameters(), lr=LR)
loader = DataLoader(TensorDataset(x_train, y_train), batch_size=BS)

losses = []
for epoch in range(EPOCHS):
    if epoch % 100 == 0:
        print('epoch {}'.format(epoch))
    epoch_losses = []
    for batch_id, (xi, yi) in enumerate(loader):
        optimizer.zero_grad()
        pred = mu_net(xi)
        loss = loss_fn(pred, yi)
        epoch_losses.append(loss.item() * xi.shape[0])
        loss.backward()
        optimizer.step()
    losses.append(np.sum(epoch_losses) / x.shape[0])

plt.figure()
plt.plot(losses)
plt.show()

plt.figure(figsize=(15, 7))
plt.plot(x.cpu(), y.cpu(), 'ro')
plt.plot(x_test.cpu(), mu_net(x_test).detach().cpu(), label='predictions')
plt.plot(x_test.cpu(), y_test.cpu(), label='true')
plt.show()
# Out:
# epoch 0
# epoch 100
# epoch 200
# epoch 300
# epoch 400

# %%
residuals = mu_net(full_X) - full_Y

# %%
lengthscale = 0.1
epsilon = 1e-5
cov = (residuals@residuals.T) * torch.exp(-torch.cdist(full_X, full_X).pow(2)/(2 * lengthscale ** 2)) + epsilon * torch.eye(full_X.shape[0]).to(device=device)

# %%
dis = MultivariateNormal(torch.zeros(full_X.shape[0]), cov)

# %%
plt.figure(figsize=(20, 9))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.plot(full_X.cpu(), full_Y.cpu(), 'ro')
    plt.plot(full_X.cpu(), mu_net(full_X).detach().cpu().squeeze() + dis.sample(), 'bx')
    plt.plot(x_test.cpu(), mu_net(x_test).detach().cpu(), label='predictions')
    plt.plot(x_test.cpu(), y_test.cpu(), label='true')
    plt.legend()
    
plt.show()

# %% [markdown]
# ### Visualize Data

# %%
class MyData(Dataset):
    def __init__(self, num_samples=1000):
        self.num_samples = num_samples
        self.x_dim = 1  # x and y dim are fixed for this dataset.
        self.y_dim = 1

        # Generate data
        self.data = []
        for i in range(num_samples):
            x = full_X
            y = mu_net(full_X).detach() + dis.sample().unsqueeze(1)
            self.data.append((x, y))

    def __getitem__(self, index):
        return self.data[index]

    def __len__(self):
        return self.num_samples

# %%
# Create dataset
dataset = MyData(num_samples=2000)

# %%
# Visualize data samples
n = 15
color = iter(cm.rainbow(np.linspace(0, 1, n)))
for i in range(n):
    x, y = dataset[i] 
    x_sorted, indices = torch.sort(x, 0)
    y_sorted = y[indices.squeeze()]
    plt.plot(x_sorted.numpy(), y_sorted.numpy(), c=next(color), alpha=0.5)

# %% [markdown]
# ### Build Neural Process

# %%
from neural_process import NeuralProcess

x_dim = 1
y_dim = 1
r_dim = 100  # Dimension of representation of context points
z_dim = 200  # Dimension of sampled latent variable
h_dim = 200  # Dimension of hidden layers in encoder and decoder

neuralprocess = NeuralProcess(x_dim, y_dim, r_dim, z_dim, h_dim)

# %% [markdown]
# ### Visualize samples from prior
#
# We can visualize the prior (i.e. the output of the neural process without any context points) before training.

# %%
# Create a set of 100 target points, with shape 
# (batch_size, num_points, x_dim), which in this case is
# (1, 100, 1)
x_target = torch.Tensor(np.linspace(-1.5, 1.5, 100))
x_target = x_target.unsqueeze(1).unsqueeze(0)

for i in range(64):
    z_sample = torch.randn((1, z_dim))  # Shape (batch_size, z_dim)
    # Map x_target and z to p_y_target (which is parameterized by a 
    # normal with mean mu and std dev sigma)
    mu, _ = neuralprocess.xz_to_y(x_target, z_sample)
    # Plot predicted mean at each target point (note we could also
    # sample from distribution but plot mean for simplicity)
    plt.plot(x_target.numpy()[0], mu.detach().numpy()[0], 
             c='b', alpha=0.5)

# %% [markdown]
# ### Train Neural Process

# %%
from torch.utils.data import DataLoader
from training import NeuralProcessTrainer

batch_size = 2
num_context = 16
num_target = 16

data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
optimizer = torch.optim.Adam(neuralprocess.parameters(), lr=3e-4)
np_trainer = NeuralProcessTrainer(device, neuralprocess, optimizer,
                                  num_context_range=(num_context, num_context),
                                  num_extra_target_range=(num_target, num_target), 
                                  print_freq=200)

neuralprocess.training = True
np_trainer.train(data_loader, 30)
# Out:
# iteration 200, loss 22.609
# iteration 400, loss 0.892
# iteration 600, loss -8.790
# iteration 800, loss -12.519
# iteration 1000, loss -25.073
# Epoch: 0, Avg_loss: 7.729653907289184
# iteration 1200, loss -20.642
# iteration 1400, loss -22.026
# iteration 1600, loss -18.460
# iteration 1800, loss -29.581
# iteration 2000, loss -16.624
# Epoch: 1, Avg_loss: -22.680767154411072
# iteration 2200, loss -29.216
# iteration 2400, loss -28.792
# iteration 2600, loss -22.092
# iteration 2800, loss -31.640
# iteration 3000, loss -22.612
# Epoch: 2, Avg_loss: -26.03427223138858
# iteration 3200, loss -27.197
# iteration 3400, loss -22.356
# iteration 3600, loss -28.477
# iteration 3800, loss -28.895
# iteration 4000, loss -26.754
# Epoch: 3, Avg_loss: -26.206639103794245
# iteration 4200, loss -29.919
# iteration 4400, loss -20.320
# iteration 4600, loss -25.227
# iteration 4800, loss -34.623
# iteration 5000, loss -24.733
# Epoch: 4, Avg_loss: -26.80151485386457
# iteration 5200, loss -29.814
# iteration 5400, loss -23.527
# iteration 5600, loss -28.791
# iteration 5800, loss -27.852
# iteration 6000, loss -18.089
# Epoch: 5, Avg_loss: -26.05148846537613
# iteration 6200, loss -23.007
# iteration 6400, loss -29.209
# iteration 6600, loss -30.422
# iteration 6800, loss -33.099
# iteration 7000, loss -23.864
# Epoch: 6, Avg_loss: -27.04779051407234
# iteration 7200, loss -23.502
# iteration 7400, loss -25.208
# iteration 7600, loss -20.896
# iteration 7800, loss -18.944
# iteration 8000, loss -33.158
# Epoch: 7, Avg_loss: -26.79575446357084
# iteration 8200, loss -29.344
# iteration 8400, loss -28.496
# iteration 8600, loss -30.358
# iteration 8800, loss -24.749
# iteration 9000, loss -25.953
# Epoch: 8, Avg_loss: -27.266113356906025
# iteration 9200, loss -27.353
# iteration 9400, loss -27.021
# iteration 9600, loss -20.076
# iteration 9800, loss -23.154
# iteration 10000, loss -27.779
# Epoch: 9, Avg_loss: -26.615876694640107
# iteration 10200, loss -24.190
# iteration 10400, loss -28.545
# iteration 10600, loss -33.628
# iteration 10800, loss -31.127
# iteration 11000, loss -31.839
# Epoch: 10, Avg_loss: -27.34073374303045
# iteration 11200, loss -31.661
# iteration 11400, loss -30.119
# iteration 11600, loss -23.440
# iteration 11800, loss -26.068
# iteration 12000, loss -23.253
# Epoch: 11, Avg_loss: -27.03403359670194
# iteration 12200, loss -27.120
# iteration 12400, loss -31.929
# iteration 12600, loss -20.229
# iteration 12800, loss -33.230
# iteration 13000, loss -24.136
# Epoch: 12, Avg_loss: -27.209989540335506
# iteration 13200, loss -21.914
# iteration 13400, loss -21.472
# iteration 13600, loss -29.400
# iteration 13800, loss -31.675
# iteration 14000, loss -35.957
# Epoch: 13, Avg_loss: -26.337853798131796
# iteration 14200, loss -24.773
# iteration 14400, loss -24.102
# iteration 14600, loss -27.414
# iteration 14800, loss -23.237
# iteration 15000, loss -29.750
# Epoch: 14, Avg_loss: -27.484832180343663
# iteration 15200, loss -23.176
# iteration 15400, loss -31.701
# iteration 15600, loss -25.919
# iteration 15800, loss -25.745
# iteration 16000, loss -33.015
# Epoch: 15, Avg_loss: -27.563426247101823
# iteration 16200, loss -23.531
# iteration 16400, loss -35.419
# iteration 16600, loss -25.058
# iteration 16800, loss -26.906
# iteration 17000, loss -27.873
# Epoch: 16, Avg_loss: -27.07761624729935
# iteration 17200, loss -26.247
# iteration 17400, loss -34.932
# iteration 17600, loss -26.140
# iteration 17800, loss -27.314
# iteration 18000, loss -30.641
# Epoch: 17, Avg_loss: -27.683471402662022

# %% [markdown]
# ### Visualize samples from trained prior
#
# The prior should now encode some information about the shapes of the functions.

# %%
x_target = torch.Tensor(np.linspace(-1.5, 1.5, 100))
x_target = x_target.unsqueeze(1).unsqueeze(0)

for i in range(64):
    z_sample = torch.randn((1, z_dim))
    mu, _ = neuralprocess.xz_to_y(x_target, z_sample)
    plt.plot(x_target.numpy()[0], mu.detach().numpy()[0], 
             c='b', alpha=0.5)

# %% [markdown]
# ### Visualize samples from posterior

# %%
from utils import context_target_split

# Extract a batch from data_loader
for batch in data_loader:
    break

# Use batch to create random set of context points
x, y = batch
num_context = 61
num_target = 1
x_context, y_context, _, _ = context_target_split(x[0:1], y[0:1], 
                                                  num_context, 
                                                  num_target)

# Create a set of target points corresponding to entire [-pi, pi] range
x_target = torch.Tensor(np.linspace(-1.5, 1.5, 100))
x_target = x_target.unsqueeze(1).unsqueeze(0)

neuralprocess.training = False

for i in range(64):
    # Neural process returns distribution over y_target
    p_y_pred = neuralprocess(x_context, y_context, x_target)
    # Extract mean of distribution
    mu = p_y_pred.loc.detach()
    plt.plot(x_target.numpy()[0], mu.numpy()[0], 
             alpha=0.05, c='b')

plt.scatter(x_context[0].numpy(), y_context[0].numpy(), c='k')

# %%
x[0:1].shape
# Out:
# torch.Size([1, 62, 1])
